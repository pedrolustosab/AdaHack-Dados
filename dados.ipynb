# %%
#AdaHack

# %% [markdown]
# ###Proposta do AdaHack
#
# A Corp Solutions, uma empresa líder no mercado de tecnologia para recursos humanos, recentemente recebeu um aporte milionário de uma grande corporação dos Estados Unidos. Como parte de seu compromisso em se tornar uma referência no mercado e em promover um ambiente de trabalho diverso e inclusivo, a Corp Solutions identificou a necessidade de aumentar a diversidade dentro de sua própria equipe.
#
# * Identificar oportunidades de aumentar a diversidade na Corp Solutions. Desenvolver soluções criativas, aplicáveis e inovadoras para promover a inclusão e equidade no ambiente de trabalho. Contribuir para a construção de uma cultura organizacional diversa, inclusiva e sustentável.

# %%
#Importando as bibliotecas
import pandas as pd
import numpy as np

# Ignorar avisos
import warnings
warnings.filterwarnings('ignore')

#Banco de dados
from sqlalchemy import create_engine
from sqlalchemy.exc import SQLAlchemyError

# Visualização
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots

# %%
df = pd.read_csv('base_de_dados.csv')

# %%
df.head(5)
# Out:
#    id  id.1                                     Nome Genero  Idade  RaÃ§a  \
# 0   1     1  Eleonora Arilda Penedo Gomes de Padilha    Fem   34.0  pardo
# 1   2     2         ElisÃ¢ngela Gabrielle de OsÃ³rio    Fem   26.0  pardo
# 2   3     3                   JosÃ© TÃºlio de Cabral   Masc   35.0  pardo
# 3   4     4      Ezequiel Edivaldo de Medeiros Sonao   Masc   24.0  pardo
# 4   5     5                 Fagner Josiel dos Santos   Masc   21.0  pardo
#
#                                            EndereÃ§o       FormaÃ§Ã£o  \
# 0            9155 Harold Oval\nSellersside, FL 21337    Ensino MÃ©dio
# 1        941 Martin Manor\nLake Isaiahtown, FM 43797    Ensino MÃ©dio
# 2             110 Davis Ridges\nMejiaville, LA 17095    Ensino MÃ©dio
# 3  48010 Wilson Glen Apt. 749\nSmithborough, NV 0...  Ensino Superior
# 4    8666 Ramos Ports Apt. 070\nSandraport, MN 33570  Ensino Superior
#
#            Estado  Tempo de casa      Departamento       Senioridade
# 0  Santa Catarina           12.0           Compras    Analista Pleno
# 1           ParÃ¡            6.0     Contabilidade  Analista JÃºnior
# 2  Santa Catarina            5.0            Vendas    Analista Pleno
# 3       Tocantins            4.0    Administrativo           Gerente
# 4          CearÃ¡            5.0  Recursos Humanos  Analista JÃºnior

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             10000 non-null  int64
#  1   id.1           10000 non-null  int64
#  2   Nome           10000 non-null  object
#  3   Genero         10000 non-null  object
#  4   Idade          9944 non-null   float64
#  5   RaÃ§a          10000 non-null  object
#  6   EndereÃ§o      10000 non-null  object
#  7   FormaÃ§Ã£o     9956 non-null   object
#  8   Estado         10000 non-null  object
#  9   Tempo de casa  9800 non-null   float64
#  10  Departamento   10000 non-null  object
#  11  Senioridade    10000 non-null  object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 937.6+ KB

# %%
#Verificando duplicadas
df.duplicated().sum()
# Out:
# 0

# %%
#Verificando se a nulos
df.isnull().sum()
# Out:
# id                 0
# id.1               0
# Nome               0
# Genero             0
# Idade             56
# RaÃ§a              0
# EndereÃ§o          0
# FormaÃ§Ã£o        44
# Estado             0
# Tempo de casa    200
# Departamento       0
# Senioridade        0
# dtype: int64

# %% [markdown]
# Nesse dataset original temos 12 colunas e 10000 linhas, entretanto pudemos identificar que os dados não estão tratados, possuindo caracteres quebrados e dados com valores ausentes. Diante disso vamos realizar o tratamento dos dados para uma análise mais exploratória.

# %% [markdown]
# Inicialmente começamos conectando ao banco de dados do Postgres e vamos criar um dataframe dos dados salvos na tabela.

# %%
# conectar postgres DB
try:
    # Criar a string de conexão usando SQLAlchemy
    db_string = "postgresql://postgres:adahack2024@db-adahack.cfevcennalmb.us-east-1.rds.amazonaws.com:5432/postgres"
    # Criar engine SQLAlchemy
    engine = create_engine(db_string)
except:
    print("Connection failed")

# %% [markdown]
# Criamos o banco de dados para armazenar os dados tratados, buscando facilitar a análise e elaboração de gráficos do mesmo

# %%
def decode_text(text):
    '''Tratando caracteres mal interpretados'''

    if isinstance(text, str):
        latin1_bytes = text.encode('latin-1', errors='ignore')
        corrected_text = latin1_bytes.decode('utf-8', errors='ignore')
        return corrected_text
    else:
        return text

df = pd.read_csv('base_de_dados.csv', encoding='utf-8', header=None).applymap(decode_text)

print(df)
# Out:
#           0      1                                        2       3      4   \
# 0         id     id                                     Nome  Genero  Idade
# 1          1      1  Eleonora Arilda Penedo Gomes de Padilha     Fem   34.0
# 2          2      2           Elisângela Gabrielle de Osório     Fem   26.0
# 3          3      3                     José Túlio de Cabral    Masc   35.0
# 4          4      4      Ezequiel Edivaldo de Medeiros Sonao    Masc   24.0
# ...      ...    ...                                      ...     ...    ...
# 9996    9996   9996                       Omar Camilo da Paz    Masc   21.0
# 9997    9997   9997                Edu de Muniz Jinuyul Neto    Masc   44.0
# 9998    9998   9998                  Benedito Robert Dlievic    Masc   21.0
# 9999    9999   9999                   Bento Osvaldo do Piauí    Masc   39.0
# 10000  10000  10000           Augusto José do Rio de Tavares    Masc   35.0
#
#            5                                                  6   \
# 0        Raça                                           Endereço
# 1       pardo            9155 Harold Oval\nSellersside, FL 21337
# 2       pardo        941 Martin Manor\nLake Isaiahtown, FM 43797
# 3       pardo             110 Davis Ridges\nMejiaville, LA 17095
# 4       pardo  48010 Wilson Glen Apt. 749\nSmithborough, NV 0...
# ...       ...                                                ...
# 9996    pardo          47323 Casey Junction\nJaimefort, UT 49158
# 9997    pardo  1431 Gina Gardens Apt. 534\nJohnsonshire, GU 8...
# 9998   branco          41179 Tracie Parkways\nLangfort, IA 88137
# 9999    pardo                902 Luis Island\nBrownton, NJ 61984
# 10000  branco  72486 Diaz Springs Suite 182\nNew Thomasview, ...
#
#                     7                 8              9   \
# 0             Formação            Estado  Tempo de casa
# 1         Ensino Médio    Santa Catarina           12.0
# 2         Ensino Médio              Pará            6.0
# 3         Ensino Médio    Santa Catarina            5.0
# 4      Ensino Superior         Tocantins            4.0
# ...                ...               ...            ...
# 9996   Ensino Superior          Rondônia            9.0
# 9997      Ensino Médio           Paraíba           10.0
# 9998   Ensino Superior  Distrito Federal            6.0
# 9999   Ensino Superior            Paraná            5.0
# 10000  Ensino Superior        Pernambuco            2.0
#
#                                 10               11
# 0                     Departamento      Senioridade
# 1                          Compras   Analista Pleno
# 2                    Contabilidade  Analista Júnior
# 3                           Vendas   Analista Pleno
# 4                   Administrativo          Gerente
# ...                            ...              ...
# 9996                 Contabilidade  Analista Júnior
# 9997                 Contabilidade  Analista Júnior
# 9998   Desenvolvimento de Produtos          Gerente
# 9999                        Vendas  Analista Júnior
# 10000                       Vendas   Analista Pleno
#
# [10001 rows x 12 columns]

# %%
# Corrigindo os cabeçalhos
df.columns = df.iloc[0]
df = df[1:]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 1 to 10000
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             10000 non-null  object
#  1   id             10000 non-null  object
#  2   Nome           10000 non-null  object
#  3   Genero         10000 non-null  object
#  4   Idade          9944 non-null   object
#  5   Raça           10000 non-null  object
#  6   Endereço       10000 non-null  object
#  7   Formação       9956 non-null   object
#  8   Estado         10000 non-null  object
#  9   Tempo de casa  9800 non-null   object
#  10  Departamento   10000 non-null  object
#  11  Senioridade    10000 non-null  object
# dtypes: object(12)
# memory usage: 937.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 1 to 10000
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             10000 non-null  object
#  1   id             10000 non-null  object
#  2   Nome           10000 non-null  object
#  3   Genero         10000 non-null  object
#  4   Idade          9944 non-null   object
#  5   Raça           10000 non-null  object
#  6   Endereço       10000 non-null  object
#  7   Formação       9956 non-null   object
#  8   Estado         10000 non-null  object
#  9   Tempo de casa  9800 non-null   object
#  10  Departamento   10000 non-null  object
#  11  Senioridade    10000 non-null  object
# dtypes: object(12)
# memory usage: 937.6+ KB

# %%
#Substituindo valores nulos
df.dropna(subset=['Idade','Formação','Tempo de casa'],inplace= True)
df
# Out:
# <ipython-input-22-873552f924d8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['Idade','Formação','Tempo de casa'],inplace= True)
# 0         id     id                                     Nome Genero Idade  \
# 1          1      1  Eleonora Arilda Penedo Gomes de Padilha    Fem  34.0
# 2          2      2           Elisângela Gabrielle de Osório    Fem  26.0
# 3          3      3                     José Túlio de Cabral   Masc  35.0
# 4          4      4      Ezequiel Edivaldo de Medeiros Sonao   Masc  24.0
# 5          5      5                 Fagner Josiel dos Santos   Masc  21.0
# ...      ...    ...                                      ...    ...   ...
# 9996    9996   9996                       Omar Camilo da Paz   Masc  21.0
# 9997    9997   9997                Edu de Muniz Jinuyul Neto   Masc  44.0
# 9998    9998   9998                  Benedito Robert Dlievic   Masc  21.0
# 9999    9999   9999                   Bento Osvaldo do Piauí   Masc  39.0
# 10000  10000  10000           Augusto José do Rio de Tavares   Masc  35.0
#
# 0        Raça                                           Endereço  \
# 1       pardo            9155 Harold Oval\nSellersside, FL 21337
# 2       pardo        941 Martin Manor\nLake Isaiahtown, FM 43797
# 3       pardo             110 Davis Ridges\nMejiaville, LA 17095
# 4       pardo  48010 Wilson Glen Apt. 749\nSmithborough, NV 0...
# 5       pardo    8666 Ramos Ports Apt. 070\nSandraport, MN 33570
# ...       ...                                                ...
# 9996    pardo          47323 Casey Junction\nJaimefort, UT 49158
# 9997    pardo  1431 Gina Gardens Apt. 534\nJohnsonshire, GU 8...
# 9998   branco          41179 Tracie Parkways\nLangfort, IA 88137
# 9999    pardo                902 Luis Island\nBrownton, NJ 61984
# 10000  branco  72486 Diaz Springs Suite 182\nNew Thomasview, ...
#
# 0             Formação            Estado Tempo de casa  \
# 1         Ensino Médio    Santa Catarina          12.0
# 2         Ensino Médio              Pará           6.0
# 3         Ensino Médio    Santa Catarina           5.0
# 4      Ensino Superior         Tocantins           4.0
# 5      Ensino Superior             Ceará           5.0
# ...                ...               ...           ...
# 9996   Ensino Superior          Rondônia           9.0
# 9997      Ensino Médio           Paraíba          10.0
# 9998   Ensino Superior  Distrito Federal           6.0
# 9999   Ensino Superior            Paraná           5.0
# 10000  Ensino Superior        Pernambuco           2.0
#
# 0                     Departamento      Senioridade
# 1                          Compras   Analista Pleno
# 2                    Contabilidade  Analista Júnior
# 3                           Vendas   Analista Pleno
# 4                   Administrativo          Gerente
# 5                 Recursos Humanos  Analista Júnior
# ...                            ...              ...
# 9996                 Contabilidade  Analista Júnior
# 9997                 Contabilidade  Analista Júnior
# 9998   Desenvolvimento de Produtos          Gerente
# 9999                        Vendas  Analista Júnior
# 10000                       Vendas   Analista Pleno
#
# [9701 rows x 12 columns]

# %%
# Corrigindo dados das colunas


df['Tempo de casa'] = df['Tempo de casa'].astype(float).astype(int)
df.loc[df['Tempo de casa'] < 0, 'Tempo de casa'] = -1

df['Idade'] = df['Idade'].astype(float).astype(int)

df['Endereço'] = df['Endereço'].str.replace('\n', ' ')

df['Genero'] = df['Genero'].replace({'Fem': 'F', 'Masc': 'M'})

lista_de_estados = {
                    'Acre':'AC',
                    'Alagoas':'AL',
                    'Amapá':'AP',
                    'Amazonas':'AM',
                    'Bahia':'BA',
                    'Ceará':'CE',
                    'Distrito Federal':'DF',
                    'Espírito Santo':'ES',
                    'Goiás':'GO',
                    'Maranhão':'MA',
                    'Mato Grosso':'MT',
                    'Mato Grosso do Sul':'MS',
                    'Minas Gerais':'MG',
                    'Pará':'PA',
                    'Paraíba':'PB',
                    'Paraná':'PR',
                    'Pernambuco':'PE',
                    'Piauí':'PI',
                    'Rio de Janeiro':'RJ',
                    'Rio Grande do Norte':'RN',
                    'Rio Grande do Sul':'RS',
                    'Rondônia':'RO',
                    'Roraima':'RR',
                    'Santa Catarina':'SC',
                    'São Paulo':'SP',
                    'Sergipe':'SE',
                    'Tocantins':'TO'}

df['Estado_UF'] = df['Estado'].replace(lista_de_estados)
# Out:
# <ipython-input-23-c1d29451a778>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Tempo de casa'] = df['Tempo de casa'].astype(float).astype(int)
# <ipython-input-23-c1d29451a778>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Idade'] = df['Idade'].astype(float).astype(int)
# <ipython-input-23-c1d29451a778>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Endereço'] = df['Endereço'].str.replace('\n', ' ')
# <ipython-input-23-c1d29451a778>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Genero'] = df['Genero'].replace({'Fem': 'F', 'Masc': 'M'})
# <ipython-input-23-c1d29451a778>:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Estado_UF'] = df['Estado'].replace(lista_de_estados)

# %%
# Padronizando cabeçalhos
df.rename(columns={'Raça': 'Raca', 'Endereço': 'Endereco', 'Formação': 'Formacao', 'Tempo de casa': 'Tempo_de_casa'}, inplace=True)
# Out:
# <ipython-input-24-89d62f72ff4d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Raça': 'Raca', 'Endereço': 'Endereco', 'Formação': 'Formacao', 'Tempo de casa': 'Tempo_de_casa'}, inplace=True)

# %%
# Retirando coluna repetida
df.drop(['id'], axis=1, inplace=True)
# Out:
# <ipython-input-25-b5d35a8b12b5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['id'], axis=1, inplace=True)

# %%
nome_tabela = "colaboradores"
# Salvar o DataFrame no banco de dados usando o engine SQLAlchemy
try:
    df.to_sql(nome_tabela, engine, index=False, if_exists='replace')
    print("Dados salvos com sucesso na tabela", nome_tabela)
except Exception as e:
    print("Erro ao salvar os dados na tabela:", e)
# Out:
# Dados salvos com sucesso na tabela colaboradores

# %%
# criar um dataframe a partir dos dados salvos na tabela colaboradores
colaboradores_db = "SELECT * FROM public.colaboradores"
df_db = pd.read_sql(colaboradores_db, db_string)
df_db
# Out:
#                                          Nome Genero  Idade    Raca  \
# 0     Eleonora Arilda Penedo Gomes de Padilha      F     34   pardo
# 1              Elisângela Gabrielle de Osório      F     26   pardo
# 2                        José Túlio de Cabral      M     35   pardo
# 3         Ezequiel Edivaldo de Medeiros Sonao      M     24   pardo
# 4                    Fagner Josiel dos Santos      M     21   pardo
# ...                                       ...    ...    ...     ...
# 9696                       Omar Camilo da Paz      M     21   pardo
# 9697                Edu de Muniz Jinuyul Neto      M     44   pardo
# 9698                  Benedito Robert Dlievic      M     21  branco
# 9699                   Bento Osvaldo do Piauí      M     39   pardo
# 9700           Augusto José do Rio de Tavares      M     35  branco
#
#                                                Endereco         Formacao  \
# 0              9155 Harold Oval\r Sellersside, FL 21337     Ensino Médio
# 1          941 Martin Manor\r Lake Isaiahtown, FM 43797     Ensino Médio
# 2               110 Davis Ridges\r Mejiaville, LA 17095     Ensino Médio
# 3     48010 Wilson Glen Apt. 749\r Smithborough, NV ...  Ensino Superior
# 4      8666 Ramos Ports Apt. 070\r Sandraport, MN 33570  Ensino Superior
# ...                                                 ...              ...
# 9696         47323 Casey Junction\r Jaimefort, UT 49158  Ensino Superior
# 9697  1431 Gina Gardens Apt. 534\r Johnsonshire, GU ...     Ensino Médio
# 9698         41179 Tracie Parkways\r Langfort, IA 88137  Ensino Superior
# 9699               902 Luis Island\r Brownton, NJ 61984  Ensino Superior
# 9700  72486 Diaz Springs Suite 182\r New Thomasview,...  Ensino Superior
#
#                 Estado  Tempo_de_casa                 Departamento  \
# 0       Santa Catarina             12                      Compras
# 1                 Pará              6                Contabilidade
# 2       Santa Catarina              5                       Vendas
# 3            Tocantins              4               Administrativo
# 4                Ceará              5             Recursos Humanos
# ...                ...            ...                          ...
# 9696          Rondônia              9                Contabilidade
# 9697           Paraíba             10                Contabilidade
# 9698  Distrito Federal              6  Desenvolvimento de Produtos
# 9699            Paraná              5                       Vendas
# 9700        Pernambuco              2                       Vendas
#
#           Senioridade Estado_UF Faixa_Etaria
# 0      Analista Pleno        SC        33-37
# 1     Analista Júnior        PA        23-27
# 2      Analista Pleno        SC        33-37
# 3             Gerente        TO        23-27
# 4     Analista Júnior        CE        18-22
# ...               ...       ...          ...
# 9696  Analista Júnior        RO        18-22
# 9697  Analista Júnior        PB        43-47
# 9698          Gerente        DF        18-22
# 9699  Analista Júnior        PR        38-42
# 9700   Analista Pleno        PE        33-37
#
# [9701 rows x 12 columns]

# %% [markdown]
# Agora com os dados tratados obtivemos 9701 linhas e mantivemos 12 colunas, deletamos a coluna repetida de id e criamos uma coluna de Estado_UF para que possamos filtrar por estado na hora de criarmos os gráficos.

# %%
#Extraindo estatísticas
df.describe().T
# Out:
#                 count       mean       std  min   25%   50%   75%   max
# 0
# Idade          9701.0  30.888465  8.674880  6.0  24.0  30.0  37.0  74.0
# Tempo_de_casa  9701.0   5.497268  2.948898 -1.0   3.0   5.0   8.0  17.0

# %%
# a dispersão e a forma da distribuição de um conjunto de dados, excluindo os valores NaN.
df_describe = df.describe()

# A amplitude é a diferença entre o valor máximo e mínimo.
df_describe.loc['amp'] = df_describe.loc['max'] - df_describe.loc['min']

# O coeficiente de variação (CV) é uma medida da variabilidade relativa em relação à média.
df_describe.loc['cv'] = (df_describe.loc['std'] / df_describe.loc['mean'] ).abs() *100

# A assimetria é uma medida estatística para avaliar a assimetria na distribuição dos dados.
df_describe.loc['skewness'] = df.skew()

# Calculando o IQR para cada coluna numérica
df_describe.loc['IQR'] = df_describe.loc['75%'] - df_describe.loc['25%']

# Por fim, o código arredonda os valores para duas casas decimais e transpõe o DataFrame para melhor visualização.
df_describe.round(2).T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      95                 with np.errstate(invalid="ignore"):
# ---> 96                     return f(*args, **kwargs)
#      97             except ValueError as e:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in newfunc(values, axis, **kwargs)
#     493
# --> 494         return func(values, axis=axis, **kwargs)
#     495
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanskew(values, axis, skipna, mask)
#    1239     if not is_float_dtype(values.dtype):
# -> 1240         values = values.astype("f8")
#    1241         count = _get_counts(values.shape, mask, axis)
#
# ValueError: could not convert string to float: 'Eleonora Arilda Penedo Gomes de Padilha'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-50a355c75b7f> in <cell line: 11>()
#       9
#      10 # A assimetria é uma medida estatística para avaliar a assimetria na distribuição dos dados.
# ---> 11 df_describe.loc['skewness'] = df.skew()
#      12
#      13 # Calculando o IQR para cada coluna numérica
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in skew(self, axis, skipna, numeric_only, **kwargs)
#   11575             **kwargs,
#   11576         ):
# > 11577             return NDFrame.skew(self, axis, skipna, numeric_only, **kwargs)
#   11578
#   11579         setattr(cls, "skew", skew)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in skew(self, axis, skipna, numeric_only, **kwargs)
#   11221         **kwargs,
#   11222     ) -> Series | float:
# > 11223         return self._stat_function(
#   11224             "skew", nanops.nanskew, axis, skipna, numeric_only, **kwargs
#   11225         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11156         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11157
# > 11158         return self._reduce(
#   11159             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10517         # After possibly _get_data and transposing, we are now in the
#   10518         #  simple case where we can use BlockManager.reduce
# > 10519         res = df._mgr.reduce(blk_func)
#   10520         out = df._constructor(res).iloc[0]
#   10521         if out_dtype is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in reduce(self, func)
#    1532         res_blocks: list[Block] = []
#    1533         for blk in self.blocks:
# -> 1534             nbs = blk.reduce(func)
#    1535             res_blocks.extend(nbs)
#    1536
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in reduce(self, func)
#     337         assert self.ndim == 2
#     338
# --> 339         result = func(self.values)
#     340
#     341         if self.values.ndim == 1:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in blk_func(values, axis)
#   10480                 return values._reduce(name, skipna=skipna, **kwds)
#   10481             else:
# > 10482                 return op(values, axis=axis, skipna=skipna, **kwds)
#   10483
#   10484         def _get_data() -> DataFrame:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#     101                 # object arrays that contain strings
#     102                 if is_object_dtype(args[0]):
# --> 103                     raise TypeError(e) from e
#     104                 raise
#     105
#
# TypeError: could not convert string to float: 'Eleonora Arilda Penedo Gomes de Padilha'
